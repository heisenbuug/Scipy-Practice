# %%
from scipy.fftpack import fft2, ifft2, fftshift
import matplotlib.pyplot as plt

# %%
image = plt.imread('corner.png')

# %%
frequency = fftshift(fft2(image))
plt.figure()
ax1 = plt.subplot2grid((1, 1), (0, 0), colspan = 2)
plt.axis('equal')
plt.imshow(image)

# %%
ax2 = plt.subplot2grid((2,2), (1,0)) 
plt.imshow(adjust_log(module))
ax3 = plt.subplot2grid((2,2), (1,1))
plt.imshow(angles)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-5c946558451a> in <module>()
#       1 ax2 = plt.subplot2grid((2,2), (1,0))
# ----> 2 plt.imshow(adjust_log(module))
#       3 ax3 = plt.subplot2grid((2,2), (1,1))
#       4 plt.imshow(angles)
#       5 plt.show()
#
# NameError: name 'adjust_log' is not defined
